# %% [markdown]
# ## **USA Housing Price Prediction: -**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("USA_Housing.csv")
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
# dtypes: float64(6)
# memory usage: 234.5 KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
import ml_stats as stats_lib

# %%
for col_name in df.columns:
    print(col_name)
    stats_obj = stats_lib.ml_stats(df[col_name])
    stats_obj.stats_process()
# Out:
# Avg. Area Income
# Total: 342915544.91985
# Length: 5000
# Maximum Value: 107701.7484
# Minimum value: 17796.63119
# Range of Data: 89905.11721
# Mean: 68583.10898397
# Median: 68804.28640499999
# No Mode found. Computer is fine
# Quartile 1: 61480.56239
# Quartile 3: 75783.33866499999
# IQR: 14302.77627499999
# Lower Whisker: 40026.39797750002
# Upper Whisker: 97237.50307749998
# Total Outliers Count: 32
# Variance 113570058.15998553
# Standard Deviation 10656.92536147202
# 1 Standard Deviation Range: 57926.18 to 79240.03 --> 68.72% of data
# 2 Standard Deviation Range: 47269.26 to 89896.96 --> 95.40% of data
# 3 Standard Deviation Range: 36612.33 to 100553.89 --> 99.74% of data
# Skewness: -0.03369974605287991
# Kurtosis: 0.043110890763585985
# Likely follows Normal Distribution
# 95% Confidence Interval: 68287.71 to 68878.50
# 97% Confidence Interval: 68256.06 to 68910.15
# 99% Confidence Interval: 68194.88 to 68971.34
# Detected Continuous Data
# Avg. Area House Age
# ...

# %%
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# dtype: int64

# %% [markdown]
# ## **Machine Learning Flow: -**
#
# 1) Defining Problem Statement
# 2) Collecting Data
# 3) Reading Data in Python
# 4) Data Preprocessing (There are 14-15 more steps inside Data Preprocessing)
# 5) Defining Input & Output
# 6) Train Test Split
# 7) Training ML Model
# 8) Evaluating Model
# 9) Save Model
# 10) Deploy Model
#
# ### **Overfit: -**
# Overfit occurs when model memorises training data.
# Here, Training Accuracy > Testing Accuracy.
#
# ### **Underfit: -**
# Underfit occurs when a model does not learn at all.
# Here, Training Accurary AND Testing Accuracy are BOTH LOW.
#
# ### **BestFit: -**
# Bestfit is the best model.
# Here, Testing Accurarcy >= Training Accuracy.

# %% [markdown]
# ## **Splitting the data: -**

# %%
X = df.drop("Price", axis = 1)
y = df["Price"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 555)

# %%
X_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3185       66469.36947             4.663863                   6.117542
# 3159       72847.98842             5.947064                   6.459059
# 3102       62088.70090             7.053111                   7.113968
# 120        67310.03695             7.193793                   7.760733
# 2567       57730.32200             5.105381                   9.001899
# ...                ...                  ...                        ...
# 233        60575.16244             5.907566                   6.964616
# 1430       73422.83220             5.327630                   4.693947
# 2628       76113.36653             5.625762                   7.067777
# 1057       71240.25164             5.924127                   8.885192
# 4782       83284.54506             7.609567                   6.309589
#
#       Avg. Area Number of Bedrooms  Area Population
# 3185                          4.13      22670.60862
# ...

# %%
print("Shape of df:", df.shape)
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of df: (5000, 6)
# Shape of X_train: (4000, 5)
# Shape of X_test: (1000, 5)
# Shape of y_train: (4000,)
# Shape of y_test: (1000,)

# %% [markdown]
# ## **Building Multi Linear Regression Machine Learning Model: -**

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([1181284.06440964, 1237560.74841433,  644398.70453434,
#        1768262.7852998 , 1515840.40010457, 1192407.94962408,
#        1346135.32793359, 1424059.84985176, 1202496.65929103,
#        1498034.92966206, 1398560.05822375, 1389337.51843022,
#        1462615.32142079, 1219486.84185537,  873361.89377089,
#        1427519.8140838 , 1288781.88584821,  783575.01218088,
#        1004091.70094622,  888434.24388861,  578268.2475152 ,
#        1389891.24006121, 1714287.31462336, 1493484.62855513,
#        1052802.80567356, 1038048.89622892,  969716.03354064,
#        1162352.17230249,  991945.45846961, 1404315.05209079,
#         827471.81294494, 1098376.93765419,  843103.11723441,
#        1080683.57020925, 1155948.51107017,  951836.80110959,
#        1092927.94988141,  715300.67076639, 1362940.72321756,
#        1267905.2734944 ,  833582.79095349, 1525097.35214566,
#         808454.46313621, 1331738.77843979,  695370.95518696,
# ...

# %%
col_index = 0
for i in lr.coef_:
    print(df.columns[col_index])
    print("Slope", round(i, 2))
    col_index += 1
    print("*"*30)
    print("y-intercept:", lr.intercept_)
# Out:
# Avg. Area Income
# Slope 21.59
# ******************************
# y-intercept: -2630570.442159578
# Avg. Area House Age
# Slope 164499.23
# ******************************
# y-intercept: -2630570.442159578
# Avg. Area Number of Rooms
# Slope 119970.77
# ******************************
# y-intercept: -2630570.442159578
# Avg. Area Number of Bedrooms
# Slope 2059.82
# ******************************
# y-intercept: -2630570.442159578
# Area Population
# Slope 15.29
# ******************************
# y-intercept: -2630570.442159578

# %% [markdown]
# We have finished building the model. y_pred variable above has all the predicted values. It predicts using the formula y = mx + c where it takes all the values of x1 and multiplies with the slope(m) + x2 * m2... + xn * mn + c.

# %% [markdown]
# ## **Finding Error: -**

# %%
# Without Library
sse = sum((y_test - y_pred)**2)
print("Sum of Squared Error:", sse)

mse = sse/len(X_test)
print("Mean Squared Error:", mse)

rmse = np.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Sum of Squared Error: 10012400493466.924
# Mean Squared Error: 10012400493.466925
# Root Mean Squared Error: 100061.98325771344

# %%
# With Library
from sklearn.metrics import mean_squared_error
error = np.sqrt(mean_squared_error(y_test, y_pred))
print("Error:", round(error, 2))
# Out:
# Error: 100061.98

# %%
sns.displot(y_test - y_pred);

# %% [markdown]
# This means most of the time our model does not make any error. But sometimes the predicted value is off by -300000 to 300000.

# %%
for i in df.iloc[2452].values:
    print(i)
# Out:
# 77521.05738
# 6.444728491
# 7.077553855
# 5.43
# 32624.6465
# 1501622.125

# %%
income = float(input("What is your Income"))
age = float(input("What is the age of your house"))
rooms = float(input("How many rooms does your house have"))
bedroom = float(input("How many bedrooms does your house have"))
pop = float(input("What is the population of your area"))

user_input = np.array([income, age, rooms, bedroom, pop])
# Out:
# What is your Income 77521
# What is the age of your house 6
# How many rooms does your house have 7
# How many bedrooms does your house have 5
# What is the population of your area 32624

# %%
house_price_pred = lr.predict(user_input.reshape(1, -1))
print(f"Your house can be sold between ${round(house_price_pred[0] - 50000)} to ${round(house_price_pred[0]) + 50000}")
# Out:
# Your house can be sold between $1329257 to $1429257

# %% [markdown]
# ## **Saving the Model: -**

# %%
import joblib
joblib.dump(lr, "USA house price pred model with 100k rmse on 25-08-25.pkl")
# Out:
# ['USA house price pred model with 100k rmse on 25-08-25.pkl']
